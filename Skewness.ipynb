# %% [markdown]
# <a href="https://colab.research.google.com/github/RonakkudalAI/Data-Analysis/blob/main/Skewness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.Series([2,3,5,6,8,20])
print(df)
# Out:
# 0     2
# 1     3
# 2     5
# 3     6
# 4     8
# 5    20
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df,bins=6,kde=True)
# Out:
# <Axes: ylabel='Count'>
