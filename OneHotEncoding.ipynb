# %% [markdown]
# <a href="https://colab.research.google.com/github/RonakkudalAI/Data-Analysis/blob/main/OneHotEncoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Gender':['Male','Female'],
                    'Smoker':['Yes','No']
                   })
on_encoder = pd.get_dummies(df)
print(on_encoder)
# Out:
#    Gender_Female  Gender_Male  Smoker_No  Smoker_Yes
# 0          False         True      False        True
# 1           True        False       True       False

# %%
on_encoder = pd.get_dummies(df,dtype=int)
print(on_encoder)
# Out:
#    Gender_Female  Gender_Male  Smoker_No  Smoker_Yes
# 0              0            1          0           1
# 1              1            0          1           0

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
on_encoderr = OneHotEncoder(sparse_output =False,dtype = int)
on_encoder_enc = on_encoderr.fit_transform(df)
print(on_encoder_enc)
# Out:
# [[0 1 0 1]
#  [1 0 1 0]]
